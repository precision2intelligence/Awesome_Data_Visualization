# %% [markdown]
# # 使用Pyecharts绘制桑基图

# %% [markdown]
# ## 导入依赖库Sankey

# %%
from pyecharts import Sankey

# %% [markdown]
# #### 因为要导入json格式的数据，所以这里额外导入了两个json相关库。如果是字典格式，则不需要导入

# %%
import json
import codecs

# %% [markdown]
# ## 准备节点和边的数据

# %%
with codecs.open(("energy.json"), "r", encoding="utf-8") as f:
    j = json.load(f)
    nodes=j["nodes"]
    links=j["links"]

# %% [markdown]
# ## 创建一个桑基图对象
# ### sankey = Sankey(name, **kwargs)
# #### 可选参数有：
# #### name(str):桑基图的名称
# #### width(int):画布宽度
# #### height(int):画布高度
# #### subtitle(str):副标题，支持换行
# #### 标题字号、颜色、位置、画布颜色、是否开启动画等，都可以通过参数设置，不额外设置的采用默认值

# %%
sankey = Sankey("能源流向桑基图", width=1000, height=600,subtitle = '这是\n第一张图')

# %% [markdown]
# ## 图表主题设置
# #### 默认主题是“dark”
# #### 更换主题需要安装 echarts-themes-pypkg插件，可以使用pip安装
# #### 支持自定义主题

# %%
sankey.use_theme("roma")
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'roma': '/nbextensions/echarts-themes-js/roma'
#         }
#     });
# </script>
#     <div id="4685271c26b04c7a9a919aa825a98e18" style="width:1000px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'roma'], function(echarts) {
#
# var myChart_4685271c26b04c7a9a919aa825a98e18 = echarts.init(document.getElementById('4685271c26b04c7a9a919aa825a98e18'), 'roma', {renderer: 'canvas'});
#
# var option_4685271c26b04c7a9a919aa825a98e18 = {
#     "tooltip": {},
#     "toolbox": {
#         "show": true,
#         "top": "center",
#         "left": "95%",
#         "orient": "vertical",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series": [],
#     "legend": [
#         {
#             "data": []
#         }
#     ],
#     "series_id": 5548603,
#     "title": [
#         {
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "left": "auto",
#             "text": "\u80fd\u6e90\u6d41\u5411\u6851\u57fa\u56fe",
#             "subtext": "\u8fd9\u662f\n\u7b2c\u4e00\u5f20\u56fe",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "top": "auto"
#         }
#     ],
#     "animation": true
# };
# myChart_4685271c26b04c7a9a919aa825a98e18.setOption(option_4685271c26b04c7a9a919aa825a98e18);
#
#     });
# </script>

# %% [markdown]
# ## Sankey.add() 方法
# ### add(name, nodes, links,
# ###    sankey_node_width=20,
# ###    sankey_node_gap=8, **kwargs)
# #### 必选参数有：（有些非必要参数能使图片美化，也作为必选参数）
# #### name(str):图例名称
# #### nodes(list):节点列表，列表中有成对出现的“name”和“节点名”
# #### links(list):边列表，列表中有成组出现的“source”，“target”和“value”，用字典好，每个字典三个键值对
# #### line_opacity(float):边的透明度
# #### line_curve(float):边的弯曲度，不建议大于1
# #### line_color(str):"source"和流出节点颜色一致，"target"和流入节点颜色一致
# #### sankey_node_width(int):节点宽度，默认为20
# #### sankey_node_gap(int):每一列节点间距，默认为8

# %%
sankey.add(
    "这里是图例名称",
    nodes,
    links,
    line_opacity=0.2,
    line_curve=0.5,
    line_color="source",
    sankey_node_width=15,
    sankey_node_gap=8,
    is_label_show=True,#是否显示节点名
    label_pos="right",#节点名称位置
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'roma': '/nbextensions/echarts-themes-js/roma'
#         }
#     });
# </script>
#     <div id="4685271c26b04c7a9a919aa825a98e18" style="width:1000px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'roma'], function(echarts) {
#
# var myChart_4685271c26b04c7a9a919aa825a98e18 = echarts.init(document.getElementById('4685271c26b04c7a9a919aa825a98e18'), 'roma', {renderer: 'canvas'});
#
# var option_4685271c26b04c7a9a919aa825a98e18 = {
#     "tooltip": {
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333",
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "trigger": "item",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "triggerOn": "mousemove|click"
#     },
#     "toolbox": {
#         "show": true,
#         "top": "center",
#         "left": "95%",
#         "orient": "vertical",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series": [
#         {
#             "nodeGap": 8,
#             "type": "sankey",
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "curveness": 0.5,
#                     "color": "source",
#                     "type": "solid",
#                     "opacity": 0.2
#                 }
#             },
#             "data": [
#                 {
#                     "name": "Agricultural 'waste'"
#                 },
#                 {
#                     "name": "Bio-conversion"
#                 },
#                 {
#                     "name": "Liquid"
#                 },
#                 {
#                     "name": "Losses"
#                 },
#                 {
#                     "name": "Solid"
#                 },
#                 {
#                     "name": "Gas"
#                 },
#                 {
#                     "name": "Biofuel imports"
#                 },
#                 {
#                     "name": "Biomass imports"
#                 },
#                 {
#                     "name": "Coal imports"
#                 },
#                 {
#                     "name": "Coal"
#                 },
#                 {
#                     "name": "Coal reserves"
#                 },
#                 {
#                     "name": "District heating"
#                 },
#                 {
#                     "name": "Industry"
#                 },
#                 {
#                     "name": "Heating and cooling - commercial"
#                 },
#                 {
#                     "name": "Heating and cooling - homes"
#                 },
#                 {
#                     "name": "Electricity grid"
#                 },
#                 {
#                     "name": "Over generation / exports"
#                 },
#                 {
#                     "name": "H2 conversion"
#                 },
#                 {
#                     "name": "Road transport"
#                 },
#                 {
#                     "name": "Agriculture"
#                 },
#                 {
#                     "name": "Rail transport"
#                 },
#                 {
#                     "name": "Lighting & appliances - commercial"
#                 },
#                 {
#                     "name": "Lighting & appliances - homes"
#                 },
#                 {
#                     "name": "Gas imports"
#                 },
#                 {
#                     "name": "Ngas"
#                 },
#                 {
#                     "name": "Gas reserves"
#                 },
#                 {
#                     "name": "Thermal generation"
#                 },
#                 {
#                     "name": "Geothermal"
#                 },
#                 {
#                     "name": "H2"
#                 },
#                 {
#                     "name": "Hydro"
#                 },
#                 {
#                     "name": "International shipping"
#                 },
#                 {
#                     "name": "Domestic aviation"
#                 },
#                 {
#                     "name": "International aviation"
#                 },
#                 {
#                     "name": "National navigation"
#                 },
#                 {
#                     "name": "Marine algae"
#                 },
#                 {
#                     "name": "Nuclear"
#                 },
#                 {
#                     "name": "Oil imports"
#                 },
#                 {
#                     "name": "Oil"
#                 },
#                 {
#                     "name": "Oil reserves"
#                 },
#                 {
#                     "name": "Other waste"
#                 },
#                 {
#                     "name": "Pumped heat"
#                 },
#                 {
#                     "name": "Solar PV"
#                 },
#                 {
#                     "name": "Solar Thermal"
#                 },
#                 {
#                     "name": "Solar"
#                 },
#                 {
#                     "name": "Tidal"
#                 },
#                 {
#                     "name": "UK land based bioenergy"
#                 },
#                 {
#                     "name": "Wave"
#                 },
#                 {
#                     "name": "Wind"
#                 }
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "right",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "nodeWidth": 15,
#             "links": [
#                 {
#                     "target": 1,
#                     "source": 0,
#                     "value": 124.729
#                 },
#                 {
#                     "target": 2,
#                     "source": 1,
#                     "value": 0.597
#                 },
#                 {
#                     "target": 3,
#                     "source": 1,
#                     "value": 26.862
#                 },
#                 {
#                     "target": 4,
#                     "source": 1,
#                     "value": 280.322
#                 },
#                 {
#                     "target": 5,
#                     "source": 1,
#                     "value": 81.144
#                 },
#                 {
#                     "target": 2,
#                     "source": 6,
#                     "value": 35
#                 },
#                 {
#                     "target": 4,
#                     "source": 7,
#                     "value": 35
#                 },
#                 {
#                     "target": 9,
#                     "source": 8,
#                     "value": 11.606
#                 },
#                 {
#                     "target": 9,
#                     "source": 10,
#                     "value": 63.965
#                 },
#                 {
#                     "target": 4,
#                     "source": 9,
#                     "value": 75.571
#                 },
#                 {
#                     "target": 12,
#                     "source": 11,
#                     "value": 10.639
#                 },
#                 {
#                     "target": 13,
#                     "source": 11,
#                     "value": 22.505
#                 },
#                 {
#                     "target": 14,
#                     "source": 11,
#                     "value": 46.184
#                 },
#                 {
#                     "target": 16,
#                     "source": 15,

# %% [markdown]
# ## 渲染图片
# #### sankey.render(path)
# #### 不设置path，在文件目录下生成render.html文件
# #### path(str):在指定位置生成svg, png, jpeg, gif,pdf等格式的文件（需要安装pyecharts-snapshot)

# %%
sankey.render()
sankey.render(path="E:/桑基图demo.pdf")
# Out:
# phantomjs version: 2.1.1
#
# Generating file ...
# File saved in E:/桑基图demo.pdf
